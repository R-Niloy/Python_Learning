# %%
 'I'M GOING TO RUN.'
# Out:
#   File "<ipython-input-1-7cb968b25c19>", line 1
#     'I'M GOING TO RUN.'
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # this will run because of double quote

# %%
 " 'I'M GOING TO RUN.'"
# Out:
# " 'I'M GOING TO RUN.'"

# %% [markdown]
# THIS WORKS.

# %%
print("hello")
# Out:
# hello

# %%
"hello world 99"
"hello world 909"
# Out:
# 'hello world 909'

# %% [markdown]
# Just print the last string when no print command is used
# NEXT box prints the whole.
# print function prints the string.

# %%
print("hello world 99\n"
"hello world 909")
# Out:
# hello world 99
# hello world 909

# %%
print('hello \n world')
# Out:
# hello
#  world

# %%
print('hello \n world')
# Out:
# hello
#  world
